# %%
# Project 02
### Alexis Root
### 02.27.2026

# %%
#Test Connection
from db_connection import get_connection
import pandas as pd

conn = get_connection("vault.txt")

df = pd.read_sql("SELECT * FROM customer LIMIT 5;", conn)
df
# Out:
# C:\Users\Lex\AppData\Local\Temp\ipykernel_22804\3173941762.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM customer LIMIT 5;", conn)
#    cust_id       fed_id cust_type_cd              address       city state  \
# 0        1  111-11-1111            I    47 Mockingbird Ln  Lynnfield    MA
# 1        2  222-22-2222            I  372 Clearwater Blvd     Woburn    MA
# 2        3  333-33-3333            I         18 Jessup Rd     Quincy    MA
# 3        4  444-44-4444            I       12 Buchanan Ln    Waltham    MA
# 4        5  555-55-5555            I         2341 Main St      Salem    NH
#
#   postal_code trial104
# 0       01940        T
# 1       01801        T
# 2       02169        T
# 3       02451        T
# 4       03079        T

# %%
#Test Invalid File Type
get_connection("wrong_file.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Test Invalid File Type
# ----> 2 get_connection("wrong_file.txt")
#
# File ~\Downloads\Masters\SQL and Python Programming\Project 02\db_connection.py:24, in get_connection(vault_filename)
#      16 def get_connection(vault_filename: str):
#      17     """
#      18     vault_filename : str
#      19         Name of file containing username (line 1)
#    (...)     22     Raises psycopg2.DatabaseError if connection fails.
#      23     """
# ---> 24     with open(vault_filename, "r", encoding="utf-8") as file:
#      25         username = file.readline().strip()
#      26         password = file.readline().strip()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wrong_file.txt'

# %%
#Test Transaction Function
from transactions import get_transactions_by_month

df_valid = get_transactions_by_month(conn, 9, 2002)
df_valid.head()
# Out:
# C:\Users\Lex\Downloads\Masters\SQL and Python Programming\Project 02\transactions.py:59: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection, params=(month, year))
#    txn_id   txn_date txn_type_cd  amount funds_avail_date teller_emp_id  \
# 0      20 2002-09-30         CDT   100.0       2002-09-30          None
#
#   execution_branch_id trial104
# 0                None        T

# %%
#Invalid Date Test
df_invalid = get_transactions_by_month(conn, 13, 2002)
df_invalid
# Out:
# WARNING: Invalid month or year supplied.
#    txn_id  txn_date  txn_type_cd  amount  funds_avail_date  teller_emp_id  \
# 0      -1        -1           -1      -1                -1             -1
#
#    execution_branch_id  trial104
# 0                   -1        -1

# %%
#Test Class
from bank_manager import BankManager
manager = BankManager("vault.txt")

# %%
# Test retrieval
manager.get_month_transactions(3, 2001)
# Out:
# C:\Users\Lex\Downloads\Masters\SQL and Python Programming\Project 02\transactions.py:59: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection, params=(month, year))
#    txn_id   txn_date txn_type_cd  amount funds_avail_date teller_emp_id  \
# 0       4 2001-03-12         CDT   100.0       2001-03-12          None
# 1       5 2001-03-12         CDT   100.0       2001-03-12          None
#
#   execution_branch_id trial104
# 0                None        T
# 1                None        T

# %%
# Test plot- invalid
manager.plot_transactions_by_day(3, 1999)
# Out:
# WARNING: Invalid month or year supplied.
# No valid data to plot.

# %%
# Test plot
manager.plot_transactions_by_day(3, 2001)
# Out:
# C:\Users\Lex\Downloads\Masters\SQL and Python Programming\Project 02\transactions.py:59: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection, params=(month, year))
